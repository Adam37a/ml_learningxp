# %% [markdown]
# # SmartEnergy – EDA & Prototype
#
# Ce notebook charge les CSV déposés dans MinIO, fait une EDA rapide,
# extrait des features temporelles et entraîne un premier modèle (régression) pour la consommation.

# %%
import os, io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from minio import Minio
from dotenv import load_dotenv
import mlflow
import mlflow.sklearn

# %%
# -------------------------------
# Connexion à MinIO
# -------------------------------
load_dotenv('.env')
ENDPOINT = os.getenv('MINIO_ENDPOINT', 'localhost:9000')
ACCESS_KEY = os.getenv('MINIO_ACCESS_KEY', 'minioadmin')
SECRET_KEY = os.getenv('MINIO_SECRET_KEY', 'minioadmin123')
SECURE = os.getenv('MINIO_SECURE', 'false').lower() == 'true'
BUCKET = os.getenv('MINIO_BUCKET', 'smartcity-energy')
PREFIX = os.getenv('MINIO_PREFIX', 'raw/')


client = Minio(ENDPOINT, access_key=ACCESS_KEY, secret_key=SECRET_KEY, secure=SECURE)
print("Connexion MinIO OK →", ENDPOINT)
# Out:
# Connexion MinIO OK → localhost:9000

# %%
# -------------------------------
# Lister les objets disponibles
# -------------------------------
objects = list(client.list_objects(BUCKET, prefix=PREFIX, recursive=True))
for o in objects:
    print('📁', o.object_name)
# Out:
# 📁 raw/enedis_conso_journaliere_categorie_last6m.csv
# 📁 raw/odre_consommation_quotidienne_elec_last8w.csv
# 📁 raw/rte_eco2mix_national_tr_last30d.csv

# %%
# -------------------------------
# Fonction utilitaire : lire un CSV depuis MinIO
# -------------------------------
def read_csv_from_minio(bucket, key, sep=','):
    response = client.get_object(bucket, key)
    try:
        data = response.read()
        # détecte le séparateur
        sample = data[:500].decode('utf-8', errors='ignore')
        if ';' in sample and ',' not in sample.split('\n')[0]:
            sep = ';'
        return pd.read_csv(io.BytesIO(data), sep=sep)
    finally:
        response.close()
        response.release_conn()

# %%
# -------------------------------
# Chargement des 3 datasets
# -------------------------------
rte_key = PREFIX + 'rte_eco2mix_national_tr_last30d.csv'
odre_key = PREFIX + 'odre_consommation_quotidienne_elec_last8w.csv'
enedis_key = PREFIX + 'enedis_conso_journaliere_categorie_last6m.csv'

dfs = {}
for name, key in [('rte', rte_key), ('odre', odre_key), ('enedis', enedis_key)]:
    try:
        dfs[name] = read_csv_from_minio(BUCKET, key)
        print(f"✅ {name} chargé :", dfs[name].shape)
    except Exception as e:
        print(f"⚠️ {name} erreur :", e)
# Out:
# ✅ rte chargé : (2881, 42)
# ✅ odre chargé : (242544, 12)
# ✅ enedis chargé : (32868, 3)

# %%
# -------------------------------
# Préparation du dataset RTE
# -------------------------------
df = dfs['rte'].copy()
df.columns = (df.columns.str.strip()
              .str.lower()
              .str.replace(" - ", "_")
              .str.replace("-", "_")
              .str.replace(" ", "_"))
print("Colonnes RTE :", df.columns[:10].tolist())

# repère la colonne date et consommation
time_col = 'date_heure_std' if 'date_heure_std' in df.columns else [c for c in df.columns if 'date' in c and 'heure' in c][0]
target_col = [c for c in df.columns if 'consommation' in c][0]
print("time_col =", time_col, "| target_col =", target_col)
# Out:
# Colonnes RTE : ['périmètre', 'nature', 'date', 'heure', 'date_heure', 'consommation_(mw)', 'prévision_j_1_(mw)', 'prévision_j_(mw)', 'fioul_(mw)', 'charbon_(mw)']
# time_col = date_heure_std | target_col = consommation_(mw)

# %%
# conversion datetime
df[time_col] = pd.to_datetime(df[time_col], errors='coerce')
df = df.dropna(subset=[time_col, target_col])
df = df.sort_values(time_col)

# %%
# -------------------------------
# Feature engineering simple
# -------------------------------
df['hour'] = df[time_col].dt.hour
df['dow'] = df[time_col].dt.dayofweek
df['is_weekend'] = df['dow'].isin([5,6]).astype(int)

# %%
# -------------------------------
# Visualisation
# -------------------------------
df.plot(x=time_col, y=target_col, figsize=(10,4), title='Consommation RTE – 30 derniers jours')
plt.show()

# %%
# -------------------------------
# Baseline modèle (RandomForest)
# -------------------------------
split = int(len(df)*0.8)
train, test = df.iloc[:split], df.iloc[split:]
feats = ['hour', 'dow', 'is_weekend']

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mlflow.set_tracking_uri("file:./mlruns")
mlflow.set_experiment("baseline-rf")

with mlflow.start_run() as run:

    mlflow.log_param("model_type", "RandomForestRegressor")
    mlflow.log_param("n_estimators", 200)
    mlflow.log_param("random_state", 42)
    mlflow.log_param("features", feats)

    model = RandomForestRegressor(n_estimators=200, random_state=42)
    model.fit(train[feats], train[target_col])
    pred = model.predict(test[feats])

    mae = mean_absolute_error(test[target_col], pred)
    rmse = np.sqrt(mean_squared_error(test[target_col], pred))
    r2 = r2_score(test[target_col], pred)

    print(f"📊 MAE = {mae:.1f} | RMSE = {rmse:.1f} | R² = {r2:.3f}")
    mlflow.log_metric("mse", rmse)
    mlflow.log_metric("r2", r2)
    mlflow.log_metric("mae", mae)
    mlflow.sklearn.log_model(model, "model")
    print("RUN ID =", run.info.run_id)

# Visualisation
plt.figure(figsize=(10,4))
plt.plot(test[time_col], test[target_col], label='Réel')
plt.plot(test[time_col], pred, label='Prédit', alpha=0.7)
plt.title('Consommation réelle vs prédite')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[164], line 13
#       9 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#      11 mlflow.set_tracking_uri("file:./mlruns")
# ---> 13 with mlflow.start_run() as run:
#      15     mlflow.log_param("model_type", "RandomForestRegressor")
#      16     mlflow.log_param("n_estimators", 200)
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\tracking\fluent.py:540, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     536     user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     538 resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 540 active_run_obj = client.create_run(
#     541     experiment_id=exp_id_for_run,
#     542     tags=resolved_tags,
#     543     run_name=run_name,
#     544 )
#     546 # If SGC run resumption is enabled, set the experiment tag mapping
#     547 # SGC job_run_id to this run_id for future run resumption
#     548 if sgc_job_run_id_tag_key:
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\tracking\client.py:485, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     431 def create_run(
#     432     self,
#     433     experiment_id: str,
#    (...)
#     436     run_name: str | None = None,
#     437 ) -> Run:
#     438     """
#     439     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     440     metrics, parameters, artifacts, etc.
#    (...)
#     483         status: RUNNING
#     484     """
# --> 485     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\telemetry\track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\tracking\_tracking_service\client.py:183, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     178 # Extract user from tags
#     179 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     180 # in a later release.
#     181 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 183 return self.store.create_run(
#     184     experiment_id=experiment_id,
#     185     user_id=user_id,
#     186     start_time=start_time or get_current_time_millis(),
#     187     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     188     run_name=run_name,
#     189 )
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\store\tracking\file_store.py:699, in FileStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     695 """
#     696 Creates a run with the specified attributes.
#     697 """
#     698 experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 699 experiment = self.get_experiment(experiment_id)
#     700 if experiment is None:
#     701     raise MlflowException(
#     702         f"Could not create run under experiment with ID {experiment_id} - no such "
#     703         "experiment exists.",
#     704         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     705     )
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\store\tracking\file_store.py:508, in FileStore.get_experiment(self, experiment_id)
#     497 """
#     498 Fetch the experiment.
#     499 Note: This API will search for active as well as deleted experiments.
#    (...)
#     505     A single Experiment object if it exists, otherwise raises an Exception.
#     506 """
#     507 experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 508 experiment = self._get_experiment(experiment_id)
#     509 if experiment is None:
#     510     raise MlflowException(
#     511         f"Experiment '{experiment_id}' does not exist.",
#     512         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     513     )
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\store\tracking\file_store.py:470, in FileStore._get_experiment(self, experiment_id, view_type)
#     468 self._check_root_dir()
#     469 _validate_experiment_id(experiment_id)
# --> 470 experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     471 if experiment_dir is None:
#     472     raise MlflowException(
#     473         f"Could not find experiment with ID {experiment_id}",
#     474         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     475     )
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\store\tracking\file_store.py:266, in FileStore._get_experiment_path(self, experiment_id, view_type, assert_exists)
#     264     parents.append(self.trash_folder)
#     265 for parent in parents:
# --> 266     exp_list = find(parent, experiment_id, full_path=True)
#     267     if len(exp_list) > 0:
#     268         return exp_list[0]
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\utils\file_utils.py:192, in find(root, name, full_path)
#     180 """Search for a file in a root directory. Equivalent to:
#     181   ``find $root -name "$name" -depth 1``
#     182
#    (...)
#     189     list of matching files or directories.
#     190 """
#     191 path_name = os.path.join(root, name)
# --> 192 return list_all(root, lambda x: x == path_name, full_path)
#
# File c:\laragon\bin\python\python-3.10\lib\site-packages\mlflow\utils\file_utils.py:144, in list_all(root, filter_func, full_path)
#     132 """List all entities directly under 'dir_name' that satisfy 'filter_func'
#     133
#     134 Args:
#    (...)
#     141
#     142 """
#     143 if not is_directory(root):
# --> 144     raise Exception(f"Invalid parent directory '{root}'")
#     145 matches = [x for x in os.listdir(root) if filter_func(os.path.join(root, x))]
#     146 return [os.path.join(root, m) for m in matches] if full_path else matches
#
# Exception: Invalid parent directory '.\mlruns\.trash'

# %%
# -------------------------------
# Sauvegarde du modèle dans MinIO
# -------------------------------
from joblib import dump
from io import BytesIO
buf = BytesIO()
dump(model, buf)
buf.seek(0)

models_prefix = PREFIX.replace('raw/','models/')
client.put_object(BUCKET, models_prefix + "rf_baseline.joblib",
                  buf, length=len(buf.getvalue()),
                  content_type="application/octet-stream")
print("✅ Modèle sauvegardé :", models_prefix + "rf_baseline.joblib")
# Out:
# ✅ Modèle sauvegardé : models/rf_baseline.joblib

# %%
# -------------------------------
# Prévision 24h (pas 15 min)
# -------------------------------
with mlflow.start_run() as run:

    last_ts = df[time_col].max()
    future_idx = pd.date_range(last_ts + pd.Timedelta(minutes=15), periods=96, freq="15T")
    fut = pd.DataFrame({time_col: future_idx})
    fut['hour'] = fut[time_col].dt.hour
    fut['dow'] = fut[time_col].dt.dayofweek
    fut['is_weekend'] = fut['dow'].isin([5,6]).astype(int)
    fut['prediction'] = model.predict(fut[feats])
    pred_path = "predictions.csv"
    fut[[time_col, "prediction"]].to_csv(pred_path, index=False)
    mlflow.log_artifact(pred_path)
    print("RUN ID =", run.info.run_id)
    fut.plot(x=time_col, y='prediction', figsize=(10,4), title='Prévision consommation (prochaines 24h)')
    plt.show()
# Out:
# RUN ID = 7ffebc05a0f743599be97e193ca01f7d
# C:\Users\mjees\AppData\Local\Temp\ipykernel_12484\435525560.py:7: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_idx = pd.date_range(last_ts + pd.Timedelta(minutes=15), periods=96, freq="15T")
